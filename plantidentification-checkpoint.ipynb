# %%
import random 
random.seed(0) 

import numpy as np 
np.random.seed(0) 

import tensorflow as tf 
tf.random.set_seed(0)
# Out:
# c:\Users\sound\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
import os 
import json 
import zipfile 
from PIL import Image 

import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(os.listdir("PlantVillage"))

print(len(os.listdir("PlantVillage")))
print(os.listdir("PlantVillage")[:5])

print(len(os.listdir("PlantVillage")))
print(os.listdir("PlantVillage")[:5])

print(len(os.listdir("PlantVillage")))
print(os.listdir("PlantVillage")[:5])
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus']
# 15
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
# 15
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
# 15
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']

# %%
print(len(os.listdir("PlantVillage\Pepper__bell___Bacterial_spot")))
print(os.listdir("PlantVillage\Pepper__bell___Bacterial_spot")[:5])
# Out:
# 997
# ['0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964.JPG', '006adb74-934f-448f-a14f-62181742127b___JR_B.Spot 3395.JPG', '00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Spot 3132.JPG', '01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Spot 3262.JPG', '0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B.Spot 9169.JPG']

# %%
base_dir='PlantVillage\Potato__healthy'

# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
image_path='PlantVillage/Tomato_healthy/5d1894ec-b384-4a2a-951c-0ef866776500___GH_HL Leaf 523.4.JPG'
img=mpimg.imread(image_path)
print(img.shape)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# (256, 256, 3)

# %%
img_path='PlantVillage/Tomato_healthy/5d1894ec-b384-4a2a-951c-0ef866776500___GH_HL Leaf 523.4.JPG'
img=mpimg.imread(image_path)
print(img)
# Out:
# [[[146 142 143]
#   [156 152 153]
#   [153 149 150]
#   ...
#   [118 113 117]
#   [124 119 123]
#   [123 118 122]]
#
#  [[154 150 151]
#   [159 155 156]
#   [161 157 158]
#   ...
#   [137 132 136]
#   [110 105 109]
#   [122 117 121]]
#
#  [[135 131 132]
#   [162 158 159]
#   [142 138 139]
#   ...
#   [123 118 122]
#   [118 113 117]
#   [126 121 125]]
#
#  ...
#
#  [[ 71  71  71]
#   [ 71  71  71]
#   [ 72  72  72]
#   ...
#   [ 98  98 100]
#   [101 101 103]
#   [105 105 107]]
#
#  [[ 70  70  70]
#   [ 70  70  70]
#   [ 71  71  71]
#   ...
#   [ 99  99 101]
#   [ 99  99 101]
#   [ 99  99 101]]
#
#  [[ 72  72  72]
#   [ 72  72  72]
#   [ 72  72  72]
#   ...
#   [ 98  98 100]
#   [ 94  94  96]
#   [ 90  90  92]]]

# %%
img_size=224
batch_size=32

# %% [markdown]
# IMAGE DATA GENERATOR

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_gen=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %% [markdown]
# TRAIN GENERATOR

# %%
base_dir="PlantVillage"
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_gen=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)
train_generator=data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size,img_size),
    batch_size=batch_size,
    subset='training',
    class_mode='categorical'
)
# Out:
# Found 16516 images belonging to 15 classes.

# %%
base_dir="PlantVillage"
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_gen=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)
validation_generator=data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size,img_size),
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical'
)
# Out:
# Found 4122 images belonging to 15 classes.

# %%
from tensorflow.keras import layers, models 
model=models.Sequential()

model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(img_size,img_size,3)))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(train_generator.num_classes,activation='softmax'))
# Out:
# c:\Users\sound\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 186624)         │             0 │
# ...

# %%
model.compile(
    loss='categorical_crossentropy',  # Make sure this is a string
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# TRAINING THE MODEL

# %%
history=model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=5,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size
)
# Out:
# Epoch 1/5
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 869s 2s/step - accuracy: 0.6668 - loss: 1.1917 - val_accuracy: 0.8271 - val_loss: 0.5180
# Epoch 2/5
#   1/516 ━━━━━━━━━━━━━━━━━━━━ 11:39 1s/step - accuracy: 0.8438 - loss: 0.5193
# c:\Users\sound\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - accuracy: 0.8438 - loss: 0.5193 - val_accuracy: 0.8054 - val_loss: 0.5995
# Epoch 3/5
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 671s 1s/step - accuracy: 0.8832 - loss: 0.3558 - val_accuracy: 0.8447 - val_loss: 0.4705
# Epoch 4/5
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - accuracy: 0.7500 - loss: 0.6094 - val_accuracy: 0.8416 - val_loss: 0.4755
# Epoch 5/5
# ...

# %%
print("Evaluating model...")
val_loss,val_accuracy=model.evaluate(validation_generator,steps=validation_generator.samples // batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 27s 212ms/step - accuracy: 0.8403 - loss: 0.4983
# Validation Accuracy: 84.03%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %% [markdown]
# BUILDING PREDICTIVE SYSTEM

# %%
def load_and_preprocess_image(image_path,target_size=(224,224)):
    img=Image.open(image_path)
    img=img.resize(target_size)
    img_array=np.array(img)
    img_array=np.expand_dims(img_array,axis=0)
    img_array=img_array.astype('float32')/255.
    return img_array

def predict_image_class(model,image_path,class_indices):
    preprocessed_img=load_and_preprocess_image(image_path)
    predictions=model.predict(preprocessed_img)
    predicted_class_index=np.argmax(predictions,axis=1)[0]
    predicted_class_name=class_indices[predicted_class_index]
    return predicted_class_name

# %%
class_indices={v: k for k,v in train_generator.class_indices.items()}

# %%
class_indices
# Out:
# {0: 'Pepper__bell___Bacterial_spot',
#  1: 'Pepper__bell___healthy',
#  2: 'Potato___Early_blight',
#  3: 'Potato___Late_blight',
#  4: 'Potato___healthy',
#  5: 'Tomato_Bacterial_spot',
#  6: 'Tomato_Early_blight',
#  7: 'Tomato_Late_blight',
#  8: 'Tomato_Leaf_Mold',
#  9: 'Tomato_Septoria_leaf_spot',
#  10: 'Tomato_Spider_mites_Two_spotted_spider_mite',
#  11: 'Tomato__Target_Spot',
#  12: 'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  13: 'Tomato__Tomato_mosaic_virus',
#  14: 'Tomato_healthy'}

# %%
import json 
json.dump(class_indices,open('class_indices.json','w'))

# %%
#upload image path to find plant name and plant healthy or not
#paste image path
import numpy as np 
from PIL import Image 
image_path='static/uploads/vibrant-green-tomato-leaf-white-background-photo.jpg'
predicted_class_name=predict_image_class(model,image_path,class_indices)
print("predicted class name:",predicted_class_name)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# predicted class name: Tomato__Tomato_YellowLeaf__Curl_Virus

# %%
#upload image path to find plant name and plant healthy or not
#paste image path
import numpy as np 
from PIL import Image 
image_path='static/uploads/istockphoto-1276445035-612x612.jpg'
predicted_class_name=predict_image_class(model,image_path,class_indices)
print("predicted class name:",predicted_class_name)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# predicted class name: Tomato_Late_blight

# %%
model.save("plant_model.h5")
print("Model saved successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully
